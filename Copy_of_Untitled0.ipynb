# %% [markdown]
# <a href="https://colab.research.google.com/github/wwwwosama123-wq/colab/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet_engineer_bassem():
    print("أهلاً بك يا مهندس باسم جازم!")

greet_engineer_bassem()
# Out:
# أهلاً بك يا مهندس باسم جازم!
